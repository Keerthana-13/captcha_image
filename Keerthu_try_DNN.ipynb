# %%
#DNN Work

# %%
#======================== IMPORT PACKAGES ===========================

import numpy as np
import matplotlib.pyplot as plt 
from tkinter.filedialog import askopenfilename
import cv2
import matplotlib.image as mpimg
import warnings
warnings.filterwarnings('ignore')
from skimage.feature import greycomatrix, greycoprops

# %%
#====================== 1.READ A INPUT IMAGE =========================

filename = askopenfilename()
img = mpimg.imread(filename)
plt.imshow(img)
plt.title('Original Image')
plt.axis ('off')
plt.show()

# %%
#============================ 2.IMAGE PREPROCESSING ====================

#==== RESIZE IMAGE ====

resized_image = cv2.resize(img,(300,300))
img_resize_orig = cv2.resize(img,((50, 50)))

fig = plt.figure()
plt.title('RESIZED IMAGE')
plt.imshow(resized_image)
plt.axis ('off')
plt.show()

# %%
#==== GRAYSCALE IMAGE ====

try:            
    gray11 = cv2.cvtColor(img_resize_orig, cv2.COLOR_BGR2GRAY)
    
except:
    gray11 = img_resize_orig
   
fig = plt.figure()
plt.title('GRAY SCALE IMAGE')
plt.imshow(gray11)
plt.axis ('off')
plt.show()

# %%
#============================ 3.FEATURE EXTRACTION ====================

# === MEAN MEDIAN VARIANCE ===

mean_val = np.mean(gray11)
median_val = np.median(gray11)
var_val = np.var(gray11)
Test_features = [mean_val,median_val,var_val]


print()
print("----------------------------------------------")
print("FEATURE EXTRACTION --> MEAN, VARIANCE, MEDIAN ")
print("----------------------------------------------")
print()
print("1. Mean Value     =", mean_val)
print()
print("2. Median Value   =", median_val)
print()
print("3. Variance Value =", var_val)
# Out:
# ----------------------------------------------
# FEATURE EXTRACTION --> MEAN, VARIANCE, MEDIAN
# ----------------------------------------------
#
# 1. Mean Value     = 0.7279098
#
# 2. Median Value   = 0.827451
#
# 3. Variance Value = 0.08706759

# %%
#============================ 5. IMAGE SPLITTING ===========================

import os 

from sklearn.model_selection import train_test_split

test_data = os.listdir('Dataset/Test/')
tr_data = os.listdir('Dataset/Train/')


dot1= []
labels1 = [] 
for img11 in test_data:
        # print(img)
        img_1 = mpimg.imread('Dataset/Test//' + "/" + img11)
        img_1 = cv2.resize(img_1,((50, 50)))


        try:            
            gray = cv2.cvtColor(img_1, cv2.COLOR_BGR2GRAY)
            
        except:
            gray = img_1

        
        dot1.append(np.array(gray))
        labels1.append(1)


for img11 in tr_data:
        # print(img)
        img_1 = mpimg.imread('Dataset/Train//' + "/" + img11)
        img_1 = cv2.resize(img_1,((50, 50)))


        try:            
            gray = cv2.cvtColor(img_1, cv2.COLOR_BGR2GRAY)
            
        except:
            gray = img_1

        
        dot1.append(np.array(gray))
        labels1.append(2)

x_train, x_test, y_train, y_test = train_test_split(dot1,labels1,test_size = 0.2, random_state = 101)

print()
print("-------------------------------------")
print("       IMAGE SPLITTING               ")
print("-------------------------------------")
print()


print("Total no of data        :",len(dot1))
print("Total no of test data   :",len(x_train))
print("Total no of train data  :",len(x_test))
# Out:
# -------------------------------------
#        IMAGE SPLITTING
# -------------------------------------
#
# Total no of data        : 1001
# Total no of test data   : 800
# Total no of train data  : 201

# %%
#=============================== CLASSIFICATION =================================

from keras.utils import to_categorical

y_train1=np.array(y_train)
y_test1=np.array(y_test)

train_Y_one_hot = to_categorical(y_train1)
test_Y_one_hot = to_categorical(y_test)


x_train2=np.zeros((len(x_train),50,50,3))
for i in range(0,len(x_train)):
        x_train2[i,:,:,:]=x_train2[i]

x_test2=np.zeros((len(x_test),50,50,3))
for i in range(0,len(x_test)):
        x_test2[i,:,:,:]=x_test2[i]

# %%
#compile the model 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Flatten
model = Sequential() 

model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.add(Flatten(input_shape=(50,50,3)))
model.add(Dense(activation = "relu", input_dim = 1, units = 8, kernel_initializer = "uniform")) 
model.add(Dense(activation = "relu", units = 14,kernel_initializer = "uniform")) 
#model.add(Dense(activation = "relu", units = 20,kernel_initializer = "uniform")) 
model.add(Dense(activation = "sigmoid", units = 1,kernel_initializer = "uniform")) 
model.compile(optimizer = 'adam' , loss = 'mae',metrics=['accuracy'] )
#history1=model.fit(x_train2,train_Y_one_hot,batch_size=2,epochs=5,verbose=1)
history1 = model.fit(x_train2, train_Y_one_hot, batch_size=2, validation_data=(x_test2,test_Y_one_hot), epochs=50, verbose=1,steps_per_epoch=5)

loss= history1.history['loss']
loss=max(loss)

acc_dd=history1.history['accuracy']
acc_dd=max(acc_dd)
acc_dd=acc_dd*100

test_loss, test_acc = model.evaluate(x_test2, test_Y_one_hot)
#print(test_loss)
#print(test_acc)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 147ms/step - loss: 0.4998 - accuracy: 0.6667 - val_loss: 0.4996 - val_accuracy: 0.6667
# Epoch 2/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4994 - accuracy: 0.6667 - val_loss: 0.4992 - val_accuracy: 0.6667
# Epoch 3/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4990 - accuracy: 0.6667 - val_loss: 0.4987 - val_accuracy: 0.6667
# Epoch 4/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4986 - accuracy: 0.6667 - val_loss: 0.4983 - val_accuracy: 0.6667
# Epoch 5/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4982 - accuracy: 0.6667 - val_loss: 0.4979 - val_accuracy: 0.6667
# Epoch 6/50
# 5/5 [==============================] - 0s 55ms/step - loss: 0.4978 - accuracy: 0.6667 - val_loss: 0.4975 - val_accuracy: 0.6667
# Epoch 7/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4973 - accuracy: 0.6667 - val_loss: 0.4971 - val_accuracy: 0.6667
# Epoch 8/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4969 - accuracy: 0.6667 - val_loss: 0.4967 - val_accuracy: 0.6667
# Epoch 9/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4965 - accuracy: 0.6667 - val_loss: 0.4963 - val_accuracy: 0.6667
# Epoch 10/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4961 - accuracy: 0.6667 - val_loss: 0.4958 - val_accuracy: 0.6667
# Epoch 11/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4957 - accuracy: 0.6667 - val_loss: 0.4954 - val_accuracy: 0.6667
# Epoch 12/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4953 - accuracy: 0.6667 - val_loss: 0.4950 - val_accuracy: 0.6667
# Epoch 13/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4948 - accuracy: 0.6667 - val_loss: 0.4946 - val_accuracy: 0.6667
# Epoch 14/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4944 - accuracy: 0.6667 - val_loss: 0.4942 - val_accuracy: 0.6667
# Epoch 15/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4940 - accuracy: 0.6667 - val_loss: 0.4938 - val_accuracy: 0.6667
# Epoch 16/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4936 - accuracy: 0.6667 - val_loss: 0.4933 - val_accuracy: 0.6667
# Epoch 17/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4932 - accuracy: 0.6667 - val_loss: 0.4929 - val_accuracy: 0.6667
# Epoch 18/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4928 - accuracy: 0.6667 - val_loss: 0.4925 - val_accuracy: 0.6667
# Epoch 19/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4923 - accuracy: 0.6667 - val_loss: 0.4921 - val_accuracy: 0.6667
# Epoch 20/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4919 - accuracy: 0.6667 - val_loss: 0.4917 - val_accuracy: 0.6667
# Epoch 21/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4915 - accuracy: 0.6667 - val_loss: 0.4913 - val_accuracy: 0.6667
# Epoch 22/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4911 - accuracy: 0.6667 - val_loss: 0.4908 - val_accuracy: 0.6667
# Epoch 23/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4907 - accuracy: 0.6667 - val_loss: 0.4904 - val_accuracy: 0.6667
# Epoch 24/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4903 - accuracy: 0.6667 - val_loss: 0.4900 - val_accuracy: 0.6667
# Epoch 25/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4899 - accuracy: 0.6667 - val_loss: 0.4896 - val_accuracy: 0.6667
# Epoch 26/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4894 - accuracy: 0.6667 - val_loss: 0.4892 - val_accuracy: 0.6667
# Epoch 27/50
# 5/5 [==============================] - 0s 60ms/step - loss: 0.4890 - accuracy: 0.6667 - val_loss: 0.4888 - val_accuracy: 0.6667
# Epoch 28/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4886 - accuracy: 0.6667 - val_loss: 0.4884 - val_accuracy: 0.6667
# Epoch 29/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4882 - accuracy: 0.6667 - val_loss: 0.4879 - val_accuracy: 0.6667
# Epoch 30/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4878 - accuracy: 0.6667 - val_loss: 0.4875 - val_accuracy: 0.6667
# Epoch 31/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4874 - accuracy: 0.6667 - val_loss: 0.4871 - val_accuracy: 0.6667
# Epoch 32/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.4870 - accuracy: 0.6667 - val_loss: 0.4867 - val_accuracy: 0.6667
# Epoch 33/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4865 - accuracy: 0.6667 - val_loss: 0.4863 - val_accuracy: 0.6667
# Epoch 34/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4861 - accuracy: 0.6667 - val_loss: 0.4859 - val_accuracy: 0.6667
# Epoch 35/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4857 - accuracy: 0.6667 - val_loss: 0.4855 - val_accuracy: 0.6667
# Epoch 36/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4853 - accuracy: 0.6667 - val_loss: 0.4851 - val_accuracy: 0.6667
# Epoch 37/50
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4849 - accuracy: 0.6667 - val_loss: 0.4846 - val_accuracy: 0.6667
# Epoch 38/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4845 - accuracy: 0.6667 - val_loss: 0.4842 - val_accuracy: 0.6667
# Epoch 39/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4841 - accuracy: 0.6667 - val_loss: 0.4838 - val_accuracy: 0.6667
# Epoch 40/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4837 - accuracy: 0.6667 - val_loss: 0.4834 - val_accuracy: 0.6667
# Epoch 41/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4833 - accuracy: 0.6667 - val_loss: 0.4830 - val_accuracy: 0.6667
# Epoch 42/50
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4828 - accuracy: 0.6667 - val_loss: 0.4826 - val_accuracy: 0.6667
# Epoch 43/50
# 5/5 [==============================] - 0s 53ms/step - loss: 0.4824 - accuracy: 0.6667 - val_loss: 0.4822 - val_accuracy: 0.6667
# Epoch 44/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.4820 - accuracy: 0.6667 - val_loss: 0.4818 - val_accuracy: 0.6667
# Epoch 45/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.4816 - accuracy: 0.6667 - val_loss: 0.4814 - val_accuracy: 0.6667
# Epoch 46/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4812 - accuracy: 0.6667 - val_loss: 0.4810 - val_accuracy: 0.6667
# Epoch 47/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4808 - accuracy: 0.6667 - val_loss: 0.4806 - val_accuracy: 0.6667
# Epoch 48/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4804 - accuracy: 0.6667 - val_loss: 0.4801 - val_accuracy: 0.6667
# Epoch 49/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4800 - accuracy: 0.6667 - val_loss: 0.4797 - val_accuracy: 0.6667
# Epoch 50/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4796 - accuracy: 0.6667 - val_loss: 0.4793 - val_accuracy: 0.6667
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4793 - accuracy: 0.6667

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['accuracy'])

plt.title(' Validation Graph for DNN')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss','acc'], loc = 'upper left')
plt.show()

# %%
print("----------------------------------------------")
print("DEEP NEURAL NETWORK")
print("----------------------------------------------")
print()


print("1) Accuracy     =",acc_dd ,'%')
print()
print('2) Error rate  = ',loss,'%')
# Out:
# ----------------------------------------------
# DEEP NEURAL NETWORK
# ----------------------------------------------
#
# 1) Accuracy     = 66.66666865348816 %
#
# 2) Error rate  =  0.499833345413208 %

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# Set the figure size
plt.figure(figsize=(10, 5))

# Get the accuracy and loss data
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']


valacc=max(val_acc)
print("Validation Accuracy = ", valacc)
print()
l1=max(loss)
print("Loss rate = ", l1)
print()
valoss=max(val_loss)
print("Validation Loss = ", valoss)
print()


# Plot the accuracy data
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.gca().yaxis.set_major_formatter(mtick.FormatStrFormatter('%.6f'))
plt.tight_layout()
plt.title('Training and Validation Accuracy')
#plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Display the plot
plt.show()
# Out:
# Validation Accuracy =  0.6666670441627502
#
# Loss rate =  0.499833345413208
#
# Validation Loss =  0.4995838701725006

# %%
import cv2
import pytesseract

tessdata_dir_config = '--tessdata-dir "C:\\Program Files\\Tesseract-OCR\\tessdata"'
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

# text recognition
import matplotlib.pyplot as plt

# read image

img = cv2.imread(filename)
plt.imshow(img)
plt.show()
# configurations
config = ('-l eng --oem 1 --psm 3')
# pytesseract path
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract.exe'
text = pytesseract.image_to_string(img, config=config)
# print results
text = text.split('\n')
print(text)
# Out:
# ['']
